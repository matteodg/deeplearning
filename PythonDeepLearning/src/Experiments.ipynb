# %%
# %run experiments.py
# Out:
# After 0 iterations coeff = [0. 0. 0. 0.], error = 5565.107834483211
# After 1 iterations coeff = [1.16643088e-04 2.09584155e-06 3.86963833e-08 7.37070297e-10], error = 3427.2498316820174
# After 2 iterations coeff = [2.02615919e-04 3.66441544e-06 6.81430917e-08 1.30809148e-09], error = 2245.351653399748
# After 3 iterations coeff = [2.65982856e-04 4.84436010e-06 9.07722105e-08 1.75672407e-09], error = 1588.1748296465105
# After 4 iterations coeff = [3.12687836e-04 5.73786070e-06 1.08376339e-07 2.11514856e-09], error = 1220.0282069704483
# After 5 iterations coeff = [3.47111914e-04 6.42023409e-06 1.22276733e-07 2.40708401e-09], error = 1011.8262182443119
# After 6 iterations coeff = [3.72484199e-04 6.94699352e-06 1.33447244e-07 2.65001285e-09], error = 892.67240029765
# After 7 iterations coeff = [3.91184749e-04 7.35905570e-06 1.42605657e-07 2.85682071e-09], error = 823.4844433858328
# ...
